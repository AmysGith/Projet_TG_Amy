# %% [markdown]
# <a href="https://colab.research.google.com/github/AmysGith/Projet_TG_Amy/blob/main/TG_Dijkstra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
graph = {
    'A': [('B', 2), ('C', 5)],
    'B': [('A', 2), ('C', 1), ('D', 4)],
    'C': [('A', 5), ('B', 1), ('D', 2)],
    'D': [('B', 4), ('C', 2)]
}

contrainte = {
    'A': {'B': 7, 'C': 0},
    'B': {'A': 7, 'C': 0, 'D': 0},
    'C': {'A': 0, 'B': 0, 'D': 0},
    'D': {'B': 0, 'C': 0}
}

source = 'A'
dist = {node: float('inf') for node in graph} #dictionnaire (clé, valeur) où toutes les valeurs sont à l'infini
dist[source] = 0
unvisited = set(graph.keys()) #tableau contenant toutes les clés

while unvisited:
    current = None
    for node in unvisited:
          if current is None or dist[node] < dist[current]:
              current = node

    if dist[current] == float('inf'):
        break
    unvisited.remove(current)

    for neighbor, weight in graph[current]:
        new_dist = dist[current] + weight + contrainte[current][neighbor]
        if new_dist < dist[neighbor]:
            dist[neighbor] = new_dist

print(dist)
# Out:
# {'A': 0, 'B': 6, 'C': 5, 'D': 7}
